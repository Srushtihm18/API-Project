# %%
from streamlit import secrets
api_key = secrets["API_KEY"]

# %%
import requests

url = "https://alpha-vantage.p.rapidapi.com/query"

querystring = {"datatype":"json","keywords":"Tesla","function":"SYMBOL_SEARCH"}

headers = {
	"x-rapidapi-key": api_key,
	"x-rapidapi-host": "alpha-vantage.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'bestMatches': [{'1. symbol': 'TSLA', '2. name': 'Tesla Inc', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.8889'}, {'1. symbol': 'TL0.DEX', '2. name': 'Tesla Inc', '3. type': 'Equity', '4. region': 'XETRA', '5. marketOpen': '08:00', '6. marketClose': '20:00', '7. timezone': 'UTC+02', '8. currency': 'EUR', '9. matchScore': '0.7143'}, {'1. symbol': 'TL0.FRK', '2. name': 'Tesla Inc', '3. type': 'Equity', '4. region': 'Frankfurt', '5. marketOpen': '08:00', '6. marketClose': '20:00', '7. timezone': 'UTC+02', '8. currency': 'EUR', '9. matchScore': '0.7143'}, {'1. symbol': 'TSLA34.SAO', '2. name': 'Tesla Inc', '3. type': 'Equity', '4. region': 'Brazil/Sao Paolo', '5. marketOpen': '10:00', '6. marketClose': '17:30', '7. timezone': 'UTC-03', '8. currency': 'BRL', '9. matchScore': '0.7143'}, {'1. symbol': 'TSLA.TRT', '2. name': 'Tesla CDR (CAD Hedged)', '3. type': 'Equity', '4. region': 'Toronto', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-05', '8. currency': 'CAD', '9. matchScore': '0.6667'}, {'1. symbol': 'TL01.FRK', '2. name': 'TESLA INC. CDR DL-001', '3. type': 'Equity', '4. region': 'Frankfurt', '5. marketOpen': '08:00', '6. marketClose': '20:00', '7. timezone': 'UTC+02', '8. currency': 'EUR', '9. matchScore': '0.3846'}]}

# %%
data = response.json()
data["bestMatches"]
# Out:
# [{'1. symbol': 'TSLA',
#   '2. name': 'Tesla Inc',
#   '3. type': 'Equity',
#   '4. region': 'United States',
#   '5. marketOpen': '09:30',
#   '6. marketClose': '16:00',
#   '7. timezone': 'UTC-04',
#   '8. currency': 'USD',
#   '9. matchScore': '0.8889'},
#  {'1. symbol': 'TL0.DEX',
#   '2. name': 'Tesla Inc',
#   '3. type': 'Equity',
#   '4. region': 'XETRA',
#   '5. marketOpen': '08:00',
#   '6. marketClose': '20:00',
#   '7. timezone': 'UTC+02',
#   '8. currency': 'EUR',
#   '9. matchScore': '0.7143'},
#  {'1. symbol': 'TL0.FRK',
#   '2. name': 'Tesla Inc',
#   '3. type': 'Equity',
#   '4. region': 'Frankfurt',
#   '5. marketOpen': '08:00',
#   '6. marketClose': '20:00',
#   '7. timezone': 'UTC+02',
#   '8. currency': 'EUR',
#   '9. matchScore': '0.7143'},
#  {'1. symbol': 'TSLA34.SAO',
#   '2. name': 'Tesla Inc',
#   '3. type': 'Equity',
#   '4. region': 'Brazil/Sao Paolo',
#   '5. marketOpen': '10:00',
#   '6. marketClose': '17:30',
#   '7. timezone': 'UTC-03',
#   '8. currency': 'BRL',
#   '9. matchScore': '0.7143'},
#  {'1. symbol': 'TSLA.TRT',
#   '2. name': 'Tesla CDR (CAD Hedged)',
#   '3. type': 'Equity',
#   '4. region': 'Toronto',
#   '5. marketOpen': '09:30',
#   '6. marketClose': '16:00',
#   '7. timezone': 'UTC-05',
#   '8. currency': 'CAD',
#   '9. matchScore': '0.6667'},
#  {'1. symbol': 'TL01.FRK',
#   '2. name': 'TESLA INC. CDR DL-001',
#   '3. type': 'Equity',
#   '4. region': 'Frankfurt',
#   '5. marketOpen': '08:00',
#   '6. marketClose': '20:00',
#   '7. timezone': 'UTC+02',
#   '8. currency': 'EUR',
#   '9. matchScore': '0.3846'}]

# %%
import pandas as pd
df = pd.DataFrame(data["bestMatches"])
df.head()
# Out:
#     1. symbol                 2. name 3. type         4. region 5. marketOpen  \
# 0        TSLA               Tesla Inc  Equity     United States         09:30
# 1     TL0.DEX               Tesla Inc  Equity             XETRA         08:00
# 2     TL0.FRK               Tesla Inc  Equity         Frankfurt         08:00
# 3  TSLA34.SAO               Tesla Inc  Equity  Brazil/Sao Paolo         10:00
# 4    TSLA.TRT  Tesla CDR (CAD Hedged)  Equity           Toronto         09:30
#
#   6. marketClose 7. timezone 8. currency 9. matchScore
# 0          16:00      UTC-04         USD        0.8889
# 1          20:00      UTC+02         EUR        0.7143
# 2          20:00      UTC+02         EUR        0.7143
# 3          17:30      UTC-03         BRL        0.7143
# 4          16:00      UTC-05         CAD        0.6667

# %%
import requests

url = "https://alpha-vantage.p.rapidapi.com/query"

querystring = {"function":"TIME_SERIES_DAILY","symbol":"TSLA","outputsize":"compact","datatype":"json"}

headers = {
	"x-rapidapi-key": api_key,
	"x-rapidapi-host": "alpha-vantage.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'TSLA', '3. Last Refreshed': '2025-12-18', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2025-12-18': {'1. open': '478.1600', '2. high': '490.8600', '3. low': '473.1200', '4. close': '483.3700', '5. volume': '94135249'}, '2025-12-17': {'1. open': '488.2200', '2. high': '495.2799', '3. low': '466.2000', '4. close': '467.2600', '5. volume': '106490405'}, '2025-12-16': {'1. open': '472.2100', '2. high': '491.5000', '3. low': '465.8300', '4. close': '489.8800', '5. volume': '107608075'}, '2025-12-15': {'1. open': '469.4400', '2. high': '481.7694', '3. low': '467.6600', '4. close': '475.3100', '5. volume': '114542204'}, '2025-12-12': {'1. open': '448.0900', '2. high': '463.0100', '3. low': '441.6700', '4. close': '458.9600', '5. volume': '95656749'}, '2025-12-11': {'1. open': '448.9450', '2. high': '449.2699', '3. low': '440.3300', '4. close': '446.8900', '5. volume': '55979492'}, '2025-12-10': {'1. open': '446.0650', '2. high': '456.8800', '3. low': '443.6100', '4. close': '451.4500', '5. volume': '63257475'}, '2025-12-09': {'1. open': '437.5400', '2. high': '452.3900', '3. low': '435.7000', '4. close': '445.1700', '5. volume': '62014951'}, '2025-12-08': {'1. open': '447.4450', '2. high': '449.7463', '3. low': '435.2500', '4. close': '439.5800', '5. volume': '68386756'}, '2025-12-05': {'1. open': '453.0300', '2. high': '458.8700', '3. low': '451.6600', '4. close': '455.0000', '5. volume': '56427522'}, '2025-12-04': {'1. open': '449.9400', '2. high': '454.6300', '3. low': '445.3900', '4. close': '454.5300', '5. volume': '71906488'}, '2025-12-03': {'1. open': '432.1000', '2. high': '447.9200', '3. low': '431.1100', '4. close': '446.7400', '5. volume': '87482964'}, '2025-12-02': {'1. open': '430.8100', '2. high': '436.8000', '3. low': '422.1200', '4. close': '429.2400', '5. volume': '69336626'}, '2025-12-01': {'1. open': '425.3200', '2. high': '433.6599', '3. low': '425.2900', '4. close': '430.1400', '5. volume': '57463552'}, '2025-11-28': {'1. open': '426.5900', '2. high': '432.9300', '3. low': '426.2000', '4. close': '430.1700', '5. volume': '36252861'}, '2025-11-26': {'1. open': '423.9500', '2. high': '426.9400', '3. low': '416.8900', '4. close': '426.5800', '5. volume': '63462996'}, '2025-11-25': {'1. open': '414.4200', '2. high': '420.4800', '3. low': '405.9500', '4. close': '419.4000', '5. volume': '71915624'}, '2025-11-24': {'1. open': '402.1700', '2. high': '421.7200', '3. low': '401.0900', '4. close': '417.7800', '5. volume': '96806374'}, '2025-11-21': {'1. open': '402.3200', '2. high': '402.8000', '3. low': '383.7600', '4. close': '391.0900', '5. volume': '100460633'}, '2025-11-20': {'1. open': '414.6300', '2. high': '428.9400', '3. low': '394.7400', '4. close': '395.2300', '5. volume': '113548827'}, '2025-11-19': {'1. open': '406.1800', '2. high': '411.7800', '3. low': '398.5000', '4. close': '403.9900', '5. volume': '72047704'}, '2025-11-18': {'1. open': '405.3800', '2. high': '408.9000', '3. low': '393.7100', '4. close': '401.2500', '5. volume': '80688637'}, '2025-11-17': {'1. open': '398.7400', '2. high': '423.9600', '3. low': '398.7400', '4. close': '408.9200', '5. volume': '102214259'}, '2025-11-14': {'1. open': '386.3000', '2. high': '412.1900', '3. low': '382.7800', '4. close': '404.3500', '5. volume': '105506682'}, '2025-11-13': {'1. open': '423.1300', '2. high': '424.5000', '3. low': '396.3400', '4. close': '401.9900', '5. volume': '118948032'}, '2025-11-12': {'1. open': '442.1500', '2. high': '442.3290', '3. low': '426.5600', '4. close': '430.6000', '5. volume': '58513520'}, '2025-11-11': {'1. open': '439.4000', '2. high': '442.4900', '3. low': '432.3600', '4. close': '439.6200', '5. volume': '60533237'}, '2025-11-10': {'1. open': '439.6000', '2. high': '449.6715', '3. low': '433.3600', '4. close': '445.2300', '5. volume': '76515907'}, '2025-11-07': {'1. open': '437.9200', '2.  ...

# %%
data = response.json()
data.keys()
# Out:
# dict_keys(['Meta Data', 'Time Series (Daily)'])

# %%
daily_data = data["Time Series (Daily)"]
daily_data
# Out:
# {'2025-12-18': {'1. open': '478.1600',
#   '2. high': '490.8600',
#   '3. low': '473.1200',
#   '4. close': '483.3700',
#   '5. volume': '94135249'},
#  '2025-12-17': {'1. open': '488.2200',
#   '2. high': '495.2799',
#   '3. low': '466.2000',
#   '4. close': '467.2600',
#   '5. volume': '106490405'},
#  '2025-12-16': {'1. open': '472.2100',
#   '2. high': '491.5000',
#   '3. low': '465.8300',
#   '4. close': '489.8800',
#   '5. volume': '107608075'},
#  '2025-12-15': {'1. open': '469.4400',
#   '2. high': '481.7694',
#   '3. low': '467.6600',
#   '4. close': '475.3100',
#   '5. volume': '114542204'},
#  '2025-12-12': {'1. open': '448.0900',
#   '2. high': '463.0100',
#   '3. low': '441.6700',
#   '4. close': '458.9600',
#   '5. volume': '95656749'},
#  '2025-12-11': {'1. open': '448.9450',
#   '2. high': '449.2699',
#   '3. low': '440.3300',
#   '4. close': '446.8900',
#   '5. volume': '55979492'},
#  '2025-12-10': {'1. open': '446.0650',
#   '2. high': '456.8800',
#   '3. low': '443.6100',
#   '4. close': '451.4500',
#   '5. volume': '63257475'},
#  '2025-12-09': {'1. open': '437.5400',
#   '2. high': '452.3900',
#   '3. low': '435.7000',
#   '4. close': '445.1700',
#   '5. volume': '62014951'},
#  '2025-12-08': {'1. open': '447.4450',
#   '2. high': '449.7463',
#   '3. low': '435.2500',
#   '4. close': '439.5800',
#   '5. volume': '68386756'},
#  '2025-12-05': {'1. open': '453.0300',
#   '2. high': '458.8700',
#   '3. low': '451.6600',
#   '4. close': '455.0000',
#   '5. volume': '56427522'},
#  '2025-12-04': {'1. open': '449.9400',
#   '2. high': '454.6300',
#   '3. low': '445.3900',
#   '4. close': '454.5300',
#   '5. volume': '71906488'},
#  '2025-12-03': {'1. open': '432.1000',
#   '2. high': '447.9200',
#   '3. low': '431.1100',
#   '4. close': '446.7400',
#   '5. volume': '87482964'},
#  '2025-12-02': {'1. open': '430.8100',
#   '2. high': '436.8000',
#   '3. low': '422.1200',
#   '4. close': '429.2400',
#   '5. volume': '69336626'},
#  '2025-12-01': {'1. open': '425.3200',
#   '2. high': '433.6599',
#   '3. low': '425.2900',
#   '4. close': '430.1400',
#   '5. volume': '57463552'},
#  '2025-11-28': {'1. open': '426.5900',
#   '2. high': '432.9300',
#   '3. low': '426.2000',
#   '4. close': '430.1700',
#   '5. volume': '36252861'},
#  '2025-11-26': {'1. open': '423.9500',
#   '2. high': '426.9400',
#   '3. low': '416.8900',
#   '4. close': '426.5800',
#   '5. volume': '63462996'},
#  '2025-11-25': {'1. open': '414.4200',
#   '2. high': '420.4800',
#   '3. low': '405.9500',
#   '4. close': '419.4000',
#   '5. volume': '71915624'},
#  '2025-11-24': {'1. open': '402.1700',
#   '2. high': '421.7200',
#   '3. low': '401.0900',
#   '4. close': '417.7800',
#   '5. volume': '96806374'},
#  '2025-11-21': {'1. open': '402.3200',
#   '2. high': '402.8000',
#   '3. low': '383.7600',
#   '4. close': '391.0900',
#   '5. volume': '100460633'},
#  '2025-11-20': {'1. open': '414.6300',
#   '2. high': '428.9400',
#   '3. low': '394.7400',
#   '4. close': '395.2300',
#   '5. volume': '113548827'},
#  '2025-11-19': {'1. open': '406.1800',
#   '2. high': '411.7800',
#   '3. low': '398.5000',
#   '4. close': '403.9900',
#   '5. volume': '72047704'},
#  '2025-11-18': {'1. open': '405.3800',
#   '2. high': '408.9000',
#   '3. low': '393.7100',
#   '4. close': '401.2500',
#   '5. volume': '80688637'},
#  '2025-11-17': {'1. open': '398.7400',
#   '2. high': '423.9600',
#   '3. low': '398.7400',
#   '4. close': '408.9200',
#   '5. volume': '102214259'},
#  '2025-11-14': {'1. open': '386.3000',
#   '2. high': '412.1900',
#   '3. low': '382.7800',
#   '4. close': '404.3500',
#   '5. volume': '105506682'},
#  '2025-11-13': {'1. open': '423.1300',
#   '2. high': '424.5000',
#   '3. low': '396.3400',
#   '4. close': '401.9900',
#   '5. volume': '118948032'},
#  '2025-11-12': {'1. open': '442.1500',
#   '2. high': '442.3290',
#   '3. low': '426.5600',
#   '4. close': '430.6000',
#   '5. volume': '58513520'},
#  '2025-11-11': {'1. open': '439.4000',
#   '2. high': '442.4900',
#   '3. low': '432.3600',
#   '4. close': '439.6200',
#   '5. volume': '60533237'},
#  '2025-11-10': {'1. open': '439.6000',
#   '2. high': '449.6715',
#   '3. low': '433.3600',
#   '4. close': '445.2300',
#   '5. volume': '76515907'},
#  '2025-11-07': {'1. open': '437.9200',
#   '2. high': '439.3600',
#   '3. low': '421.8800',
#   '4. close': '429.5200',
#   '5. volume': '103471495'},
#  '2025-11-06': {'1. open': '461.9600',
#   '2. high': '467.4500',
#   '3. low': '435.0900',
#   '4. close': '445.9100',
#   '5. volume': '109622907'},
#  '2025-11-05': {'1. open': '452.0500',
#   '2. high': '466.3299',
#   '3. low': '440.7100',
#   '4. close': '462.0700',
#   '5. volume': '84911911'},
#  '2025-11-04': {'1. open': '454.4600',
#   '2. high': '460.2200',
#   '3. low': '443.6000',
#   '4. close': '444.2600',
#   '5. volume': '87756644'},
#  '2025-11-03': {'1. open': '455.9900',
#   '2. high': '474.0700',
#   '3. low': '453.8000',
#   '4. close': '468.3700',
#   '5. volume': '84595244'},
#  '2025-10-31': {'1. open': '446.7500',
#   '2. high': '458.0000',
#   '3. low': '443.6855',
#   '4. close': '456.5600',
#   '5. volume': '83135787'},
#  '2025-10-30': {'1. open': '451.0500',
#   '2. high': '455.0607',
#   '3. low': '439.6100',
#   '4. close': '440.1000',
#   '5. volume': '72447938'},
#  '2025-10-29': {'1. open': '462.5000',
#   '2. high': '465.7000',
#   '3. low': '452.6500',
#   '4. close': '461.5100',
#   '5. volume': '67983544'},
#  '2025-10-28': {'1. open': '454.7750',
#   '2. high': '467.0000',
#   '3. low': '451.6000',
#   '4. close': '460.5500',
#   '5. volume': '80185667'},
#  '2025-10-27': {'1. open': '439.9800',
#   '2. high': '460.1600',
#   '3. low': '438.6900',
#   '4. close': '452.4200',
#   '5. volume': '105867547'},
#  '2025-10-24': {'1. open': '446.8300',
#   '2. high': '451.6800',
#   '3. low': '430.1700',
#   '4. close': '433.7200',
#   '5. volume': '94727774'},
#  '2025-10-23': {'1. open': '420.0000',
#   '2. high': '449.3999',
#   '3. low': '413.9000',
#   '4. close': '448.9800',
#   '5. volume': '126709833'},
#  '2025-10-22': {'1. open': '443.4500',
#   '2. high': '445.5390',
#   '3. low': '429.0000',
#   '4. close': '438.9700',
#   '5. volume': '84023458'},
#  '2025-10-21': {'1. open': '445.7550',
#   '2. high': '449.3000',
#   '3. low': '442.0500',
#   '4. close': '442.6000',
#   '5. volume': '54412169'},
#  '2025-10-20': {'1. open': '443.8650',
#   '2. high': '449.8000',
#   '3. low': '440.6100',
#   '4. close': '447.4300',
#   '5. volume': '63718971'},
#  '2025-10-17': {'1. open': '425.5000',
#   '2. high': '441.4558',
#   '3. low': '423.6000',
#   '4. close': '439.3100',
#   '5. volume': '89331578'},
#  '2025-10-16': {'1. open': '434.7300',
#   '2. high': '439.3500',
#   '3. low': '421.3101',
#   '4. close': '428.7500',
#   '5. volume': '77189889'},
#  '2025-10-15': {'1. open': '434.9000',
#   '2. high': '440.5100',
#   '3. low': '426.3301',
#   '4. close': '435.1500',
#   '5. volume': '71558185'},
#  '2025-10-14': {'1. open': '426.7900',
#   '2. high': '434.2000',
#   '3. low': '417.8600',
#   '4. close': '429.2400',
#   '5. volume': '72669438'},
#  '2025-10-13': {'1. open': '423.5300',
#   '2. high': '436.8900',
#   '3. low': '419.7000',
#   '4. close': '435.9000',
#   '5. volume': '79552785'},
#  '2025-10-10': {'1. open': '436.5400',
#   '2. high': '443.1300',
#   '3. low': '411.4500',
#   '4. close': '413.4900',
#   '5. volume': '112107870'},
#  '2025-10-09': {'1. open': '431.8100',
#   '2. high': '436.3500',
#   '3. low': '426.1800',
#   '4. close': '435.5400',
#   '5. volume': '69339928'},
#  '2025-10-08': {'1. open': '437.5700',
#   '2. high': '441.3300',
#   '3. low': '425.2300',
#   '4. close': '438.6900',
#   '5. volume': '71192128'},
#  '2025-10-07': {'1. open': '447.8200',
#   '2. high': '452.6800',
#   '3. low': '432.4501',
#   '4. close': '433.0900',
#   '5. volume': '102296082'},
#  '2025-10-06': {'1. open': '440.7500',
#   '2. high': '453.5500',
#   '3. low': '436.6900',
#   '4. close': '453.2500',
#   '5. volume': '85324878'},
#  '2025-10-03': {'1. open': '443.2850',
#   '2. high': '446.7700',
#   '3. low': '416.5750',
#   '4. close': '429.8300',
#   '5. volume': '133188180'},
#  '2025-10-02': {'1. open': '470.5400',
#   '2. high': '470.7500',
#   '3. low': '435.5700',
#   '4. close': '436.0000',
#   '5. volume': '137008950'},
#  '2025-10-01': {'1. open': '443.8000',
#   '2. high': '462.2900',
#   '3. low': '440.7500',
#   '4. close': '459.4600',
#   '5. volume': '98122285'},
#  '2025-09-30': {'1. open': '441.5200',
#   '2. high': '445.0000',
#   '3. low': '433.1200',
#   '4. close': '444.7200',
#   '5. volume': '74357960'},
#  '2025-09-29': {'1. open': '444.3500',
#   '2. high': '450.9800',
#   '3. low': '439.5000',
#   '4. close': '443.2100',
#   '5. volume': '79491510'},
#  '2025-09-26': {'1. open': '428.3000',
#   '2. high': '440.4700',
#   '3. low': '421.0200',
#   '4. close': '440.4000',
#   '5. volume': '101628160'},
#  '2025-09-25': {'1. open': '435.2400',
#   '2. high': '435.3500',
#   '3. low': '419.0800',
#   '4. close': '423.3900',
#   '5. volume': '96746426'},
#  '2025-09-24': {'1. open': '429.8300',
#   '2. high': '444.2100',
#   '3. low': '429.0301',
#   '4. close': '442.7900',
#   '5. volume': '93133570'},
#  '2025-09-23': {'1. open': '439.8800',
#   '2. high': '440.9700',
#   '3. low': '423.7200',
#   '4. close': '425.8500',
#   '5. volume': '83422691'},
#  '2025-09-22': {'1. open': '431.1100',
#   '2. high': '444.9800',
#   '3. low': '429.1300',
#   '4. close': '434.2100',
#   '5. volume': '97108777'},
#  '2025-09-19': {'1. open': '421.8200',
#   '2. high': '429.4700',
#   '3. low': '421.7200',
#   '4. close': '426.0700',
#   '5. volume': '93131034'},
#  '2025-09-18': {'1. open': '428.8650',
#   '2. high': '432.2199',
#   '3. low': '416.5600',
#   '4. close': '416.8500',
#   '5. volume': '90454509'},
#  '2025-09-17': {'1. open': '415.7500',
#   '2. high': '428.3121',
#   '3. low': '409.6700',
#   '4. close': '425.8600',
#   '5. volume': '106133532'},
#  '2025-09-16': {'1. open': '414.4950',
#   '2. high': '423.2500',
#   '3. low': '411.4300',
#   '4. close': '421.6200',
#   '5. volume': '104285721'},
#  '2025-09-15': {'1. open': '423.1300',
#   '2. high': '425.7000',
#   '3. low': '402.4300',
#   '4. close': '410.0400',
#   '5. volume': '163823667'},
#  '2025-09-12': {'1. open': '370.9400',
#   '2. high': '396.6899',
#   '3. low': '370.2400',
#   '4. close': '395.9400',
#   '5. volume': '168156391'},
#  '2025-09-11': {'1. open': '350.1700',
#   '2. high': '368.9900',
#   '3. low': '347.6000',
#   '4. close': '368.8100',
#   '5. volume': '103756010'},
#  '2025-09-10': {'1. open': '350.5500',
#   '2. high': '356.3300',
#   '3. low': '346.0700',
#   '4. close': '347.7900',
#   '5. volume': '72121679'},
#  '2025-09-09': {'1. open': '348.4400',
#   '2. high': '350.7700',
#   '3. low': '343.8200',
#   '4. close': '346.9700',
#   '5. volume': '53815991'},
#  '2025-09-08': {'1. open': '354.6400',
#   '2. high': '358.4400',
#   '3. low': '344.8400',
#   '4. close': '346.4000',
#   '5. volume': '75208290'},
#  '2025-09-05': {'1. open': '348.0000',
#   '2. high': '355.8700',
#   '3. low': '344.6801',
#   '4. close': '350.8400',
#   '5. volume': '108989785'},
#  '2025-09-04': {'1. open': '336.1500',
#   '2. high': '338.8900',
#   '3. low': '331.4800',
#   '4. close': '338.5300',
#   '5. volume': '60711033'},
#  '2025-09-03': {'1. open': '335.2000',
#   '2. high': '343.3300',
#   '3. low': '328.5100',
#   '4. close': '334.0900',
#   '5. volume': '88238894'},
#  '2025-09-02': {'1. open': '328.2300',
#   '2. high': '333.3300',
#   '3. low': '325.6000',
#   '4. close': '329.3600',
#   '5. volume': '58391952'},
#  '2025-08-29': {'1. open': '347.2300',
#   '2. high': '348.7499',
#   '3. low': '331.7000',
#   '4. close': '333.8700',
#   '5. volume': '81145660'},
#  '2025-08-28': {'1. open': '350.9100',
#   '2. high': '353.5500',
#   '3. low': '340.2600',
#   '4. close': '345.9800',
#   '5. volume': '67903224'},
#  '2025-08-27': {'1. open': '351.9400',
#   '2. high': '355.3900',
#   '3. low': '349.1560',
#   '4. close': '349.6000',
#   '5. volume': '65519012'},
#  '2025-08-26': {'1. open': '344.9300',
#   '2. high': '351.9000',
#   '3. low': '343.7200',
#   '4. close': '351.6700',
#   '5. volume': '76651550'},
#  '2025-08-25': {'1. open': '338.9000',
#   '2. high': '349.5300',
#   '3. low': '335.0300',
#   '4. close': '346.6000',
#   '5. volume': '86670037'},
#  '2025-08-22': {'1. open': '321.6600',
#   '2. high': '340.2500',
#   '3. low': '319.6900',
#   '4. close': '340.0100',
#   '5. volume': '94016347'},
#  '2025-08-21': {'1. open': '322.0800',
#   '2. high': '324.9000',
#   '3. low': '318.6800',
#   '4. close': '320.1100',
#   '5. volume': '55744445'},
#  '2025-08-20': {'1. open': '329.2200',
#   '2. high': '331.3700',
#   '3. low': '314.6000',
#   '4. close': '323.9000',
#   '5. volume': '77481768'},
#  '2025-08-19': {'1. open': '335.7900',
#   '2. high': '340.5500',
#   '3. low': '327.8500',
#   '4. close': '329.3100',
#   '5. volume': '75956002'},
#  '2025-08-18': {'1. open': '329.6200',
#   '2. high': '336.2700',
#   '3. low': '329.5900',
#   '4. close': '335.1600',
#   '5. volume': '56956552'},
#  '2025-08-15': {'1. open': '337.6550',
#   '2. high': '339.3000',
#   '3. low': '327.0200',
#   '4. close': '330.5600',
#   '5. volume': '74319792'},
#  '2025-08-14': {'1. open': '335.7600',
#   '2. high': '340.4699',
#   '3. low': '330.4000',
#   '4. close': '335.5800',
#   '5. volume': '75000662'},
#  '2025-08-13': {'1. open': '341.5000',
#   '2. high': '348.9800',
#   '3. low': '338.2000',
#   '4. close': '339.3800',
#   '5. volume': '67838892'},
#  '2025-08-12': {'1. open': '345.0000',
#   '2. high': '345.2600',
#   '3. low': '332.9400',
#   '4. close': '340.8400',
#   '5. volume': '80690111'},
#  '2025-08-11': {'1. open': '335.0000',
#   '2. high': '346.6400',
#   '3. low': '334.1500',
#   '4. close': '339.0300',
#   '5. volume': '105320174'},
#  '2025-08-08': {'1. open': '321.4300',
#   '2. high': '335.1500',
#   '3. low': '320.9800',
#   '4. close': '329.6500',
#   '5. volume': '91200319'},
#  '2025-08-07': {'1. open': '319.7900',
#   '2. high': '322.4000',
#   '3. low': '316.1600',
#   '4. close': '322.2700',
#   '5. volume': '66658672'},
#  '2025-08-06': {'1. open': '307.8900',
#   '2. high': '320.4700',
#   '3. low': '306.9345',
#   '4. close': '319.9100',
#   '5. volume': '78523579'},
#  '2025-08-05': {'1. open': '308.9500',
#   '2. high': '312.4499',
#   '3. low': '305.5000',
#   '4. close': '308.7200',
#   '5. volume': '57961278'},
#  '2025-08-04': {'1. open': '309.0800',
#   '2. high': '312.1186',
#   '3. low': '303.0001',
#   '4. close': '309.2600',
#   '5. volume': '78683905'},
#  '2025-08-01': {'1. open': '306.2050',
#   '2. high': '309.3100',
#   '3. low': '297.8200',
#   '4. close': '302.6300',
#   '5. volume': '89121446'},
#  '2025-07-31': {'1. open': '319.6050',
#   '2. high': '321.3700',
#   '3. low': '306.1000',
#   '4. close': '308.2700',
#   '5. volume': '85270919'},
#  '2025-07-30': {'1. open': '322.1800',
#   '2. high': '324.4499',
#   '3. low': '311.6164',
#   '4. close': '319.0400',
#   '5. volume': '83931942'}}

# %%
df_daily = pd.DataFrame(daily_data).T
df_daily
# Out:
#              1. open   2. high    3. low  4. close  5. volume
# 2025-12-18  478.1600  490.8600  473.1200  483.3700   94135249
# 2025-12-17  488.2200  495.2799  466.2000  467.2600  106490405
# 2025-12-16  472.2100  491.5000  465.8300  489.8800  107608075
# 2025-12-15  469.4400  481.7694  467.6600  475.3100  114542204
# 2025-12-12  448.0900  463.0100  441.6700  458.9600   95656749
# ...              ...       ...       ...       ...        ...
# 2025-08-05  308.9500  312.4499  305.5000  308.7200   57961278
# 2025-08-04  309.0800  312.1186  303.0001  309.2600   78683905
# 2025-08-01  306.2050  309.3100  297.8200  302.6300   89121446
# 2025-07-31  319.6050  321.3700  306.1000  308.2700   85270919
# 2025-07-30  322.1800  324.4499  311.6164  319.0400   83931942
#
# [100 rows x 5 columns]

# %%
df_daily.dtypes
# Out:
# 1. open      object
# 2. high      object
# 3. low       object
# 4. close     object
# 5. volume    object
# dtype: object

# %%
df_daily = df_daily.astype(float)
df_daily.dtypes
# Out:
# 1. open      float64
# 2. high      float64
# 3. low       float64
# 4. close     float64
# 5. volume    float64
# dtype: object

# %%
df_daily.index = pd.to_datetime(df_daily.index)

# %%
df_daily
# Out:
#             1. open   2. high    3. low  4. close    5. volume
# 2025-12-18  478.160  490.8600  473.1200    483.37   94135249.0
# 2025-12-17  488.220  495.2799  466.2000    467.26  106490405.0
# 2025-12-16  472.210  491.5000  465.8300    489.88  107608075.0
# 2025-12-15  469.440  481.7694  467.6600    475.31  114542204.0
# 2025-12-12  448.090  463.0100  441.6700    458.96   95656749.0
# ...             ...       ...       ...       ...          ...
# 2025-08-05  308.950  312.4499  305.5000    308.72   57961278.0
# 2025-08-04  309.080  312.1186  303.0001    309.26   78683905.0
# 2025-08-01  306.205  309.3100  297.8200    302.63   89121446.0
# 2025-07-31  319.605  321.3700  306.1000    308.27   85270919.0
# 2025-07-30  322.180  324.4499  311.6164    319.04   83931942.0
#
# [100 rows x 5 columns]

# %%
df_daily.to_csv("TSLA.csv")

# %%
df = pd.read_csv("TSLA.csv")
df.head()
# Out:
#    Unnamed: 0  1. open   2. high  3. low  4. close    5. volume
# 0  2025-12-18   478.16  490.8600  473.12    483.37   94135249.0
# 1  2025-12-17   488.22  495.2799  466.20    467.26  106490405.0
# 2  2025-12-16   472.21  491.5000  465.83    489.88  107608075.0
# 3  2025-12-15   469.44  481.7694  467.66    475.31  114542204.0
# 4  2025-12-12   448.09  463.0100  441.67    458.96   95656749.0

# %%
import plotly.graph_objects as go

# %%
fig = go.Figure(
    data = [
        go.Candlestick(
            x = df_daily.index,
            open = df_daily["1. open"],
            high = df_daily["2. high"],
            low = df_daily["3. low"],
            close = df_daily["4. close"]
        )
    ]
)

fig.show()

# %%
import requests
import pandas as pd
import plotly.graph_objects as go
import streamlit as st


class StockAPI:

    def __init__(self):
        self.api_key = st.secrets["API_KEY"]
        self.headers = {
            "x-rapidapi-key": self.api_key,
            "x-rapidapi-host": "alpha-vantage.p.rapidapi.com"
        }
        self.url = "https://alpha-vantage.p.rapidapi.com/query"

    def search_symbol(self, company: str):        
        querystring = {"datatype":"json","keywords":company,"function":"SYMBOL_SEARCH"}
        
        response = requests.get(self.url, headers=self.headers, params=querystring)

        data = response.json()
        df = pd.DataFrame(data["bestMatches"])
        return df
    
    def get_daily_data(self, symbol: str):
        querystring = {"function":"TIME_SERIES_DAILY","symbol":symbol,"outputsize":"compact","datatype":"json"}
        response = requests.get(self.url, headers=self.headers, params=querystring)
        data = response.json()
        daily_df = pd.DataFrame(data["Time Series (Daily)"]).T
        daily_df = daily_df.astype(float)
        daily_df.index = pd.to_datetime(daily_df.index)
        return daily_df 
    
    def plot_chart(self, df: pd.DataFrame):
        fig = go.Figure(
            data = [
                go.Candlestick(
                    x = df.index,
                    open = df["1. open"],
                    high = df["2. high"],
                    low = df["3. low"],
                    close = df["4. close"]
                )
            ]
        )
        fig.update_layout(width = 1000, height = 800)
        return fig

# %%
api = StockAPI()
type(api)
# Out:
# __main__.StockAPI

# %%
api.search_symbol(company = "State bank of India")
# Out:
#   1. symbol                  2. name 3. type       4. region 5. marketOpen  \
# 0  SBIN.BSE      State Bank of India  Equity    India/Bombay         09:15
# 1     SBKFF      State Bank of India  Equity   United States         09:30
# 2   SID.FRK      State Bank of India  Equity       Frankfurt         08:00
# 3  SBID.LON  State Bank of India GDR  Equity  United Kingdom         08:00
#
#   6. marketClose 7. timezone 8. currency 9. matchScore
# 0          15:30     UTC+5.5         INR        1.0000
# 1          16:00      UTC-04         USD        1.0000
# 2          20:00      UTC+02         EUR        1.0000
# 3          16:30      UTC+01         USD        0.9048

# %%
df_sbi = api.get_daily_data(symbol = "SBIN.BSE")
df_sbi
# Out:
#             1. open  2. high  3. low  4. close  5. volume
# 2025-12-18   976.75   981.00  973.50    977.70   594574.0
# 2025-12-17   965.00   978.50  965.00    975.90   569861.0
# 2025-12-16   967.95   969.00  958.80    961.40   222081.0
# 2025-12-15   959.95   969.30  957.05    967.15   118671.0
# 2025-12-12   964.05   967.00  958.00    962.90   205217.0
# ...             ...      ...     ...       ...        ...
# 2025-07-30   799.85   803.40  796.25    801.85   154363.0
# 2025-07-29   795.35   800.20  793.10    798.90   330118.0
# 2025-07-28   808.95   809.20  796.00    797.15   389824.0
# 2025-07-25   814.35   819.00  805.55    806.50   383923.0
# 2025-07-24   819.75   821.95  810.65    815.85   323698.0
#
# [100 rows x 5 columns]

# %%
df_sbi.to_csv("SBI.csv")

# %%
chart = api.plot_chart(df_sbi)
chart

# %%
api.search_symbol(company = "Godrej")
# Out:
#         1. symbol                           2. name 3. type     4. region  \
# 0    GODREJCP.BSE     GODREJ CONSUMER PRODUCTS LTD.  Equity  India/Bombay
# 1   GODREJIND.BSE            GODREJ INDUSTRIES LTD.  Equity  India/Bombay
# 2  GODREJAGRO.BSE                Godrej Agrovet Ltd  Equity  India/Bombay
# 3  GODREJPROP.BSE             Godrej Properties Ltd  Equity  India/Bombay
# 4      540743.BSE            Godrej Agrovet Limited  Equity  India/Bombay
# 5      532424.BSE  Godrej Consumer Products Limited  Equity  India/Bombay
#
#   5. marketOpen 6. marketClose 7. timezone 8. currency 9. matchScore
# 0         09:15          15:30     UTC+5.5         INR        0.7059
# 1         09:15          15:30     UTC+5.5         INR        0.6667
# 2         09:15          15:30     UTC+5.5         INR        0.6316
# 3         09:15          15:30     UTC+5.5         INR        0.6316
# 4         09:15          15:30     UTC+5.5         INR        0.4286
# 5         09:15          15:30     UTC+5.5         INR        0.3158

# %%
df = api.get_daily_data("GODREJIND.BSE")
df
# Out:
#             1. open  2. high   3. low  4. close  5. volume
# 2025-12-18  1008.55  1011.70   990.25   1009.20     3756.0
# 2025-12-17  1004.45  1018.90  1004.45   1012.80     1714.0
# 2025-12-16  1006.75  1022.00  1006.75   1014.75     1922.0
# 2025-12-15  1002.05  1022.00  1002.05   1018.95     2356.0
# 2025-12-12  1012.75  1022.50  1005.20   1017.05     2395.0
# ...             ...      ...      ...       ...        ...
# 2025-08-05  1139.95  1142.60  1119.35   1136.70     2491.0
# 2025-08-04  1114.00  1123.90  1110.80   1119.50     3612.0
# 2025-08-01  1146.30  1146.40  1108.85   1124.35     1854.0
# 2025-07-31  1101.85  1152.90  1101.85   1146.30     5295.0
# 2025-07-30  1120.00  1140.95  1110.85   1137.85     3177.0
#
# [100 rows x 5 columns]

# %%
df.to_csv("Godrej.csv")

# %%
api.plot_chart(df)
